# %% [markdown]
# # basic plot

# %%
import pandas as pd 
import matplotlib.pyplot as plt  

iplDF = pd.read_csv('../matches.csv')
winnerSeries = iplDF["winner"].value_counts() #value_counts will return the winner series 
winnerSeries.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # We have to plot the MI vs CSK Data form the above dataframe

# %%
mIWinnerMask = iplDF['winner'] == "Mumbai Indians"

# %%
rCBWinnerMask = iplDF['winner'] == "Royal Challengers Bangalore"

# %%
winMI = iplDF[mIWinnerMask]

# %%
miVsrcb = iplDF[rCBWinnerMask | mIWinnerMask ]
miVsrcb.shape
miVsrcb["winner"].value_counts().max
# Out:
# <bound method Series.max of winner
# Mumbai Indians                 92
# Royal Challengers Bangalore    73
# Name: count, dtype: int64>

# %%
miVsrcb["winner"].value_counts().plot(kind='')
# Out:
# <Axes: xlabel='winner'>

# %% [markdown]
# # bating Vs flilting when toss win

# %%
iplDF["toss_decision"].value_counts()   #her the only two categorys so it is confussing
# Out:
# toss_decision
# field    363
# bat      273
# Name: count, dtype: int64

# %%
iplDF["toss_decision"].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='toss_decision'>

# %%
iplDF["toss_decision"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
iplDF["toss_decision"].value_counts().plot(kind='line')
# Out:
# <Axes: xlabel='toss_decision'>

# %%
iplDF["toss_decision"].value_counts().plot(kind='hex')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[285], line 1
# ----> 1 iplDF["toss_decision"].value_counts().plot(kind='hex')
#
# File /opt/anaconda3/lib/python3.12/site-packages/pandas/plotting/_core.py:960, in PlotAccessor.__call__(self, *args, **kwargs)
#     957     return plot_backend.plot(self._parent, x=x, y=y, kind=kind, **kwargs)
#     959 if kind not in self._all_kinds:
# --> 960     raise ValueError(
#     961         f"{kind} is not a valid plot kind "
#     962         f"Valid plot kinds: {self._all_kinds}"
#     963     )
#     965 # The original data structured can be transformed before passed to the
#     966 # backend. For example, for DataFrame is common to set the index as the
#     967 # `x` parameter, and return a Series with the parameter `y` as values.
#     968 data = self._parent.copy()
#
# ...

# %%
mask = iplDF["win_by_runs"] > 100

# %%
mask
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 631    False
# 632    False
# 633    False
# 634    False
# 635    False
# Name: win_by_runs, Length: 636, dtype: bool

# %%
winer = iplDF[mask]
winerTema = winer["winner"]

# %%
winerTema.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='winner'>
