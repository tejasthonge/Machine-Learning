# %%
import pandas as pd
import numpy as np

# %%
iplData = pd.read_csv('matches.csv')  #by using this function we can read all the data and store in varible

# %%
type(iplData)  #DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
iplData
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
iplData.head()  #THIS FUNCTION BASICALY PROFIED THE FIRST FIVE ROW OF DATA OR PROVIDE THE PRIVEIW OF THE DATA TO ,TO AVIDE THE LAPTOP HANG WHEN TATA I LOT OF QONTITUY
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
iplData.tail()
# Out:
#       id  season       city        date                team1  \
# 631  632    2016     Raipur  2016-05-22     Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24        Gujarat Lions
# 633  634    2016      Delhi  2016-05-25  Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27        Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29  Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 631  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 632  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 633        Kolkata Knight Riders        Kolkata Knight Riders         field
# 634          Sunrisers Hyderabad          Sunrisers Hyderabad         field
# 635  Royal Challengers Bangalore          Sunrisers Hyderabad           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 631  normal           0  Royal Challengers Bangalore            0
# ...

# %%
iplData.head(1)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  2017-04-05  Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#    result  dl_applied               winner  win_by_runs  win_by_wickets  \
# 0  normal           0  Sunrisers Hyderabad           35               0
#
#   player_of_match                                      venue      umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal  AY Dandekar
#
#     umpire2  umpire3
# 0  NJ Llong      NaN

# %%
iplData.shape() #it is atribut so do not call like this
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 iplData.shape()
#
# TypeError: 'tuple' object is not callable

# %%
iplData.shape  #it will give no of row and collums
# Out:
# (636, 18)

# %%
iplData.shape[0]
# Out:
# 636

# %%
iplData.info() #it provide the all the information of the
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               636 non-null    int64
#  1   season           636 non-null    int64
#  2   city             629 non-null    object
#  3   date             636 non-null    object
#  4   team1            636 non-null    object
#  5   team2            636 non-null    object
#  6   toss_winner      636 non-null    object
#  7   toss_decision    636 non-null    object
#  8   result           636 non-null    object
#  9   dl_applied       636 non-null    int64
#  10  winner           633 non-null    object
#  11  win_by_runs      636 non-null    int64
#  12  win_by_wickets   636 non-null    int64
#  13  player_of_match  633 non-null    object
#  14  venue            636 non-null    object
#  15  umpire1          635 non-null    object
#  16  umpire2          635 non-null    object
# ...

# %%
iplData.describe()   #this function hase the feture to  work only on numarical values only
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets  \
# count  636.000000   636.000000  636.000000   636.000000      636.000000
# mean   318.500000  2012.490566    0.025157    13.682390        3.372642
# std    183.741666     2.773026    0.156726    23.908877        3.420338
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    159.750000  2010.000000    0.000000     0.000000        0.000000
# 50%    318.500000  2012.000000    0.000000     0.000000        4.000000
# 75%    477.250000  2015.000000    0.000000    20.000000        7.000000
# max    636.000000  2017.000000    1.000000   146.000000       10.000000
#
#        umpire3
# count      0.0
# mean       NaN
# std        NaN
# min        NaN
# 25%        NaN
# 50%        NaN
# 75%        NaN
# max        NaN

# %%
#Feathing Single Row or colum  ,means we can get the series form the dataframe

# %%
winnerColum = iplData['winner']

# %%
winnerColum
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
#to fath Multiple colums form the dataframe

# %%
matheWineerData = iplData[['team1','team2','winner']] 
matheWineerData
# Out:
#                            team1                        team2  \
# 0            Sunrisers Hyderabad  Royal Challengers Bangalore
# 1                 Mumbai Indians       Rising Pune Supergiant
# 2                  Gujarat Lions        Kolkata Knight Riders
# 3         Rising Pune Supergiant              Kings XI Punjab
# 4    Royal Challengers Bangalore             Delhi Daredevils
# ..                           ...                          ...
# 631             Delhi Daredevils  Royal Challengers Bangalore
# 632                Gujarat Lions  Royal Challengers Bangalore
# 633          Sunrisers Hyderabad        Kolkata Knight Riders
# 634                Gujarat Lions          Sunrisers Hyderabad
# 635          Sunrisers Hyderabad  Royal Challengers Bangalore
#
#                           winner
# 0            Sunrisers Hyderabad
# 1         Rising Pune Supergiant
# 2          Kolkata Knight Riders
# 3                Kings XI Punjab
# 4    Royal Challengers Bangalore
# ...

# %%
type(winnerColum)
# Out:
# pandas.core.series.Series

# %%
type(matheWineerData)
# Out:
# pandas.core.frame.DataFrame

# %%
#To Find the row rom data frame --> iloc[index]

# %%
mathNo4Data = iplData.iloc[3]
mathNo4Data
# Out:
# id                                      4
# season                               2017
# city                               Indore
# date                           2017-04-08
# team1              Rising Pune Supergiant
# team2                     Kings XI Punjab
# toss_winner               Kings XI Punjab
# toss_decision                       field
# result                             normal
# dl_applied                              0
# winner                    Kings XI Punjab
# win_by_runs                             0
# win_by_wickets                          6
# player_of_match                GJ Maxwell
# venue              Holkar Cricket Stadium
# umpire1                      AK Chaudhary
# umpire2                     C Shamshuddin
# umpire3                               NaN
# Name: 3, dtype: object

# %%
type(mathNo4Data)
# Out:
# pandas.core.series.Series

# %%
mathNo4Data.shape
# Out:
# (18,)

# %%
#to find the partuclar value from the perticular row
iplData.iloc[3]['winner']
# Out:
# 'Kings XI Punjab'

# %%
type(iplData.iloc[3]['winner'])
# Out:
# str

# %%
#we can also use the slicing on it
iplData['winner'][:]
# Out:
# 0              Sunrisers Hyderabad
# 1           Rising Pune Supergiant
# 2            Kolkata Knight Riders
# 3                  Kings XI Punjab
# 4      Royal Challengers Bangalore
#                   ...
# 631    Royal Challengers Bangalore
# 632    Royal Challengers Bangalore
# 633            Sunrisers Hyderabad
# 634            Sunrisers Hyderabad
# 635            Sunrisers Hyderabad
# Name: winner, Length: 636, dtype: object

# %%
iplData['winner'][99:105:2]
# Out:
# 99      Kings XI Punjab
# 101      Mumbai Indians
# 103    Delhi Daredevils
# Name: winner, dtype: object

# %%
iplData.iloc[10:21:2]
# Out:
#     id  season       city        date                   team1  \
# 10  11    2017    Kolkata  2017-04-13         Kings XI Punjab
# 12  13    2017     Rajkot  2017-04-14  Rising Pune Supergiant
# 14  15    2017      Delhi  2017-04-15        Delhi Daredevils
# 16  17    2017  Bangalore  2017-04-16  Rising Pune Supergiant
# 18  19    2017  Hyderabad  2017-04-17     Sunrisers Hyderabad
# 20  21    2017  Hyderabad  2017-04-19     Sunrisers Hyderabad
#
#                           team2                  toss_winner toss_decision  \
# 10        Kolkata Knight Riders        Kolkata Knight Riders         field
# 12                Gujarat Lions                Gujarat Lions         field
# 14              Kings XI Punjab             Delhi Daredevils           bat
# 16  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 18              Kings XI Punjab              Kings XI Punjab         field
# 20             Delhi Daredevils          Sunrisers Hyderabad           bat
#
# ...

# %%
#we can also use the fancy indexing in iloc to row data by uing as 
iplData.iloc[[2,7,32]]
# Out:
#     id  season    city        date                        team1  \
# 2    3    2017  Rajkot  2017-04-07                Gujarat Lions
# 7    8    2017  Indore  2017-04-10  Royal Challengers Bangalore
# 32  33    2017    Pune  2017-04-29       Rising Pune Supergiant
#
#                           team2                  toss_winner toss_decision  \
# 2         Kolkata Knight Riders        Kolkata Knight Riders         field
# 7               Kings XI Punjab  Royal Challengers Bangalore           bat
# 32  Royal Challengers Bangalore  Royal Challengers Bangalore         field
#
#     result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 2   normal           0   Kolkata Knight Riders            0              10
# 7   normal           0         Kings XI Punjab            0               8
# 32  normal           0  Rising Pune Supergiant           61               0
#
#    player_of_match                                    venue  \
# ...

# %% [markdown]
# # Revision of above
#
#
# # to get the file or read the file
# # we use Following thechique or function
# # 1 read_csv("file_name")  theis funtion is used to redad the comma saprated vlaue file that contains the dataframe
# # 2 the output it is 2d teser it conssits of row and collum and the
# # 3 to get the first fist 5 value from the file we use head() function and we also use the or pass no row that we want inside brakete
# # 5 to get last five row we use the tail() function  and similar as above
# # 6 the datat structure we get form the this .csv is dataframe and we can convert it into the seial also by accasseing any row or the collum fom it
# # 7 the get all information of the dataframe we use info() function to get all info fomrm the return .csv
# # 9 if we want only integer values then we use Discrbe() function it will return all the numerical value form the dataframe
# # 10 shape it will return the shape of the (no of row , no of colums)
