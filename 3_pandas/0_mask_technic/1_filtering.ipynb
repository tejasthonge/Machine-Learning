# %% [markdown]
# #  Filtering dataframe on a condition
# -- this is know as mask thec.

# %%
import pandas as pd
import numpy as np

iplData = pd.read_csv("././matches.csv");

# %%
iplData
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
#now we are getting the list of city form above dataframe
mask = iplData['city']  == "Pune"
iplData[mask]  # this tech is collad as the mask tech.  in the mask warible it hase the true or flase depeding on the codition if
# Out:
#       id  season  city        date                        team1  \
# 1      2    2017  Pune  2017-04-06               Mumbai Indians
# 8      9    2017  Pune  2017-04-11             Delhi Daredevils
# 24    25    2017  Pune  2017-04-22          Sunrisers Hyderabad
# 28    29    2017  Pune  2017-04-26       Rising Pune Supergiant
# 32    33    2017  Pune  2017-04-29       Rising Pune Supergiant
# 37    38    2017  Pune  2017-05-01                Gujarat Lions
# 53    54    2017  Pune  2017-05-14              Kings XI Punjab
# 314  315    2012  Pune  2012-04-08                Pune Warriors
# 323  324    2012  Pune  2012-04-14          Chennai Super Kings
# 338  339    2012  Pune  2012-04-24                Pune Warriors
# 340  341    2012  Pune  2012-04-26              Deccan Chargers
# 350  351    2012  Pune  2012-05-03               Mumbai Indians
# 357  358    2012  Pune  2012-05-08                Pune Warriors
# 361  362    2012  Pune  2012-05-11  Royal Challengers Bangalore
# ...

# %% [markdown]
# # how this mask is used as our requirement
#
# supose we have to find the mathch winned by the Mumbai Indians and city of match is pune

# %%
mask1 = iplData['city'] == "Pune";
mask2 = iplData['winner'] == "Mumbai Indians";

iplData[mask1 & mask2]
# Out:
#       id  season  city        date                    team1           team2  \
# 350  351    2012  Pune  2012-05-03           Mumbai Indians   Pune Warriors
# 438  439    2013  Pune  2013-05-11            Pune Warriors  Mumbai Indians
# 604  605    2016  Pune  2016-05-01  Rising Pune Supergiants  Mumbai Indians
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 350  Mumbai Indians           bat  normal           0  Mumbai Indians
# 438   Pune Warriors           bat  normal           0  Mumbai Indians
# 604  Mumbai Indians         field  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match  \
# 350            1               0      SL Malinga
# 438            0               5      MG Johnson
# 604            0               8       RG Sharma
#
#                                        venue      umpire1       umpire2  \
# 350               Subrata Roy Sahara Stadium    Asad Rauf      S Asnani
# ...

# %%
# like above we use the masking , also we are add complex conditions
